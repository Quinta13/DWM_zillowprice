# %%
# Libraries
import pandas            as pd
import numpy             as np
import matplotlib.pyplot as plt
import warnings

from sklearn.metrics         import mean_squared_error
from sklearn.ensemble        import RandomForestRegressor
from sklearn.utils           import resample

warnings.filterwarnings('ignore')

# %%
# local file paths

dir_name = 'selezione'
region_names = np.array(['A', 'B', 'C'])
region_ids   = np.array(['1286', '2061', '3101'])

fp_Xtrain = []
fp_Xval   = []
fp_Xtest  = []
fp_ytrain = []
fp_yval   = []
fp_ytest  = []

for i in range(3):
    fp_Xtrain.append(dir_name + f'/X_train{region_names[i]}.csv')
    fp_Xval  .append(dir_name + f'/X_val{  region_names[i]}.csv')
    fp_Xtest .append(dir_name + f'/X_test{ region_names[i]}.csv')
    fp_ytrain.append(dir_name + f'/y_train{region_names[i]}.csv')
    fp_yval  .append(dir_name + f'/y_val{  region_names[i]}.csv')
    fp_ytest .append(dir_name + f'/y_test{ region_names[i]}.csv')

# %%
# Lettura dei dati

X_train = []
X_val   = []
X_test  = []
y_train = []
y_val   = []
y_test  = []

for i in range(3):
    X_train.append(pd.read_csv(fp_Xtrain[i], low_memory=False))
    X_val  .append(pd.read_csv(fp_Xval  [i], low_memory=False))        
    X_test .append(pd.read_csv(fp_Xtest [i], low_memory=False))
    y_train.append(pd.read_csv(fp_ytrain[i], low_memory=False))
    y_val  .append(pd.read_csv(fp_yval  [i], low_memory=False))        
    y_test .append(pd.read_csv(fp_ytest [i], low_memory=False))
    
X_train = np.array(X_train, dtype=object)
X_val   = np.array(X_val,   dtype=object)
X_test  = np.array(X_test,  dtype=object)
y_train = np.array(y_train, dtype=object)
y_val   = np.array(y_val,   dtype=object)
y_test  = np.array(y_test,  dtype=object)

# %%
def dimensionality(y=False):
    for i in range(3):
        print(f'X_train{region_names[i]}: {X_train[i].shape}')
        print(f'X_val{region_names[i]}:   {X_val  [i].shape}')
        print(f'X_test{region_names[i]}:  {X_test [i].shape}')
        if y:
            print(f'y_train{region_names[i]}: {y_train[i].shape}')
            print(f'y_val{region_names[i]}:   {y_val  [i].shape}')
            print(f'y_test{region_names[i]}:  {y_test [i].shape}')
            print()

# %%
dimensionality(y=True)
# Out:
# X_trainA: (26819, 41)
# X_valA:   (9006, 41)
# X_testA:  (9085, 41)
# y_trainA: (26819, 1)
# y_valA:   (9006, 1)
# y_testA:  (9085, 1)
#
# X_trainB: (8119, 34)
# X_valB:   (2658, 34)
# X_testB:  (2606, 34)
# y_trainB: (8119, 1)
# y_valB:   (2658, 1)
# y_testB:  (2606, 1)
#
# X_trainC: (64771, 48)
# X_valC:   (21908, 48)
# X_testC:  (21876, 48)
# y_trainC: (64771, 1)
# y_valC:   (21908, 1)
# y_testC:  (21876, 1)

# %% [markdown]
# Per limiti tecnici di memoria, la gestione del dataset C risulta complicata e incorre spesso in errori a run-time di cateoria __MemoryError__

# %% [markdown]
# Le macchine su cui sono eseguiti i notebook supportano operazioni su circa 30000 righe, quindi uso i 2/5 del dataset originale per la Regione C

# %%
perc = 2/5
ind  = 2
for X, y in zip([X_train, X_val, X_test], [y_train, y_val, y_test]):
    X[ind], y[ind] = resample(
        X[ind], y[ind],
        n_samples = int(perc * len(X[2]))
    )

# %%
dimensionality(y=True)
# Out:
# X_trainA: (26819, 41)
# X_valA:   (9006, 41)
# X_testA:  (9085, 41)
# y_trainA: (26819, 1)
# y_valA:   (9006, 1)
# y_testA:  (9085, 1)
#
# X_trainB: (8119, 34)
# X_valB:   (2658, 34)
# X_testB:  (2606, 34)
# y_trainB: (8119, 1)
# y_valB:   (2658, 1)
# y_testB:  (2606, 1)
#
# X_trainC: (25908, 48)
# X_valC:   (8763, 48)
# X_testC:  (8750, 48)
# y_trainC: (25908, 1)
# y_valC:   (8763, 1)
# y_testC:  (8750, 1)

# %% [markdown]
# # Subset di testing

# %%
sub_perc = [1/1000, 1/100, 1/1000] # circa 100, per testing, 2 minuti
#sub_perc = [   1/3,     1,    1/3] # circa 8000, mezz'ora
#sub_perc = [     1,     1,      1] # dataset completo, quattro ore

# %%
for i in range(3):
    print(int(len(X_train[i])*sub_perc[i]))
    print(int(len(X_val  [i])*sub_perc[i]))
    print()

X_train_sub = []
y_train_sub = []
X_val_sub = []
y_val_sub = []

for i in range(3):
    Xt_sub, yt_sub = resample(X_train[i], y_train[i], n_samples = int(sub_perc[i]*len(X_train[i])))
    Xv_sub, yv_sub = resample(X_val  [i], y_val  [i], n_samples = int(sub_perc[i]*len(X_val[i])))
    X_train_sub.append(Xt_sub)
    y_train_sub.append(yt_sub)
    X_val_sub  .append(Xv_sub)
    y_val_sub  .append(yv_sub)
# Out:
# 26
# 9
#
# 81
# 26
#
# 25
# 8

# %%
def dimensionality_sub(y=False):
    for i in range(3):
        print(f'X_train_sub{region_names[i]}: {X_train_sub[i].shape}')
        print(f'X_val_sub{region_names[i]}:   {X_val_sub  [i].shape}')
        if y:
            print(f'y_train_sub{region_names[i]}: {y_train_sub[i].shape}')
            print(f'y_val_sub{region_names[i]}:   {y_val_sub  [i].shape}')
        print()

# %%
dimensionality_sub(y=True)
# Out:
# X_train_subA: (26, 41)
# X_val_subA:   (9, 41)
# y_train_subA: (26, 1)
# y_val_subA:   (9, 1)
#
# X_train_subB: (81, 34)
# X_val_subB:   (26, 34)
# y_train_subB: (81, 1)
# y_val_subB:   (26, 1)
#
# X_train_subC: (25, 48)
# X_val_subC:   (8, 48)
# y_train_subC: (25, 1)
# y_val_subC:   (8, 1)

# %%
rf_model = []

# %% [markdown]
# # Costruzione RandomForestRegressor #

# %%
plt.rcParams.update({'font.size': 35})

# %%
def get_bias_var_mse(X, y, model):
        y_pred = model.predict(X)
        return {
            'bias': ((y - np.mean(y_pred))**2).mean(),\
            'var':  np.var(y_pred).mean(),\
            'mse':  ((y_pred - y.reshape(-1,1))**2).mean()
        }

# %%
# Costruzione RandomForestRegressor
def RandomForestRegressor_validation(X_train, y_train, X_val, y_val, verbose=False, debug=False, file_name = ''):
    
    def get_rf_reg(estimator):
        dt = RandomForestRegressor(
            n_estimators=estimator,
            # criterion = 'squared_error',
            n_jobs=-1
        )
        dt.fit(X_train, y_train)
        return dt
    
    def bias_var_mse(X, y, model):
        stats = get_bias_var_mse(X, y, model)
        return stats['bias'],\
               stats['var'],\
               stats['mse']
    
    def plot_mse(stats, name):
    
        print (f'{name}: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA')
        print()
    
        for n in ['mse', 'bias', 'var']:
        
            min_  = min(stats[n])
            best  = (np.argmin(stats[n]) * STEP) + START
            
            print (f'Punteggio finale: {stats[n][-1]} ({END}) alberi')
            print (f'Best {n}: {min_}')
            print (f'Best number of Trees: {best}')
            print()

        fig, ax = plt.subplots(figsize=(len(stats['mse'])/2, 10))
        
        ax.tick_params(axis='both', which='major', labelsize=25)
        ax.tick_params(axis='both', which='minor', labelsize=15)
        
        ax.plot(range(START, END+1, STEP),  stats['mse' ], 'o-', label='MSE')
        ax.plot(range(START, END+1, STEP),  stats['bias'], 'o-', label='BIAS')
        ax.plot(range(START, END+1, STEP),  stats['var' ], 'o-', label='VARIANCE')
        
        ax.set_title(f"{name} MSE, BIAS, VARIANCE on different Forest Tree Number", fontsize=15)
        ax.set_xlabel("Number of Trees used", fontsize=15)
        ax.grid()
        ax.legend(prop={'size': 12})
        
        if file_name != '':
             fig.savefig('images/' + file_name + '_RandomForestRegressor' + name + '.jpg')
        
    y_train = y_train.values.ravel()
    y_val   = y_val  .values.ravel()

    START =   10
    END   =  500
    STEP  =   10
    
    model_start = get_rf_reg(START)
    
    _, _, best_mse = bias_var_mse(X_val, y_val, model_start)
    
    best_estimator  = START
    best_model      = model_start
    
    info         = []
    
    train_stats  = {
        'bias' : [],
        'var'  : [],
        'mse'  : []
    }
    
    val_stats    = {
        'bias' : [],
        'var'  : [],
        'mse'  : []
    } 
    
    for estimator in range(START, END+1, STEP):
        
        if debug:
            print(f'{estimator}/{END}')
    
        model = get_rf_reg(estimator)
        
        trn_bias, trn_var, trn_mse = bias_var_mse(X_train, y_train, model)
        val_bias, val_var, val_mse = bias_var_mse(  X_val,   y_val, model)

        train_stats['bias'].append(trn_bias)
        train_stats['var' ].append(trn_var )
        train_stats['mse' ].append(trn_mse )
        
        val_stats['bias'].append(val_bias)
        val_stats['var' ].append(val_var )
        val_stats['mse' ].append(val_mse )
        
        info.append(f'Estimators: {estimator}' +\
                    f'\n(Train MSE:       {trn_mse }  - Val MSE:      {val_mse })' +\
                    f'\n(Train Bias:      {trn_bias}  - Val Bias:     {val_bias})' +\
                    f'\n(Train Variance:  {trn_var }  - Val Variance: {val_var })' )

        if(val_mse < best_mse):
            print(f'sostituisco {estimator}')
            best_mse = val_mse
            best_estimator = estimator
            best_model = model
    
    if verbose:
        print()
        print("MSE, BIAS, VARIANCE Train e Validation")
        print(*info, sep='\n')
        print()
        
    plot_mse(train_stats, "Train"     )
    plot_mse(  val_stats, "Validation")
                
    return best_model

# %%
rf_model = []

# %%
def get_rf(index, verbose=False, debug=False, file_name=''):
    if file_name == '':
        file_name = region_ids[index]
    return RandomForestRegressor_validation(
        X_train_sub[index],
        y_train_sub[index],
        X_val_sub  [index],
        y_val_sub  [index],
        verbose   = verbose,
        debug     = debug,
        file_name = file_name
    )

# %%
# %%time
rf_model.append(
    get_rf(
        0,
        verbose = False,
        debug   = False#,
        #file_name = 'Prova1'
    )
)
# Out:
# sostituisco 20
# sostituisco 30
# sostituisco 40
# sostituisco 50
# sostituisco 210
# Train: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.010190442984412188 (500) alberi
# Best mse: 0.009791850597139279
# Best number of Trees: 70
#
# Punteggio finale: 0.007198702165763942 (500) alberi
# Best bias: 0.007197582815314291
# Best number of Trees: 260
#
# Punteggio finale: 0.002991740818648243 (500) alberi
# Best var: 0.0025924384392011436
# Best number of Trees: 70
#
# Validation: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.0037571434705224527 (500) alberi
# Best mse: 0.00364003723862949
# Best number of Trees: 210
#
# Punteggio finale: 0.0033128160324385186 (500) alberi
# Best bias: 0.0031803024614945573
# Best number of Trees: 50
#
# Punteggio finale: 0.00044432743808393366 (500) alberi
# Best var: 0.00035766833626863143
# Best number of Trees: 240
#
# Wall time: 18 s

# %%
# %%time
rf_model.append(
    get_rf(
        1,
        verbose = False,
        debug   = False#,
        #file_name = 'Prova2'
    )
)
# Out:
# sostituisco 30
# sostituisco 340
# sostituisco 380
# Train: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.023531356335317468 (500) alberi
# Best mse: 0.022679001394858855
# Best number of Trees: 100
#
# Punteggio finale: 0.016285137743307573 (500) alberi
# Best bias: 0.016263445034984055
# Best number of Trees: 130
#
# Punteggio finale: 0.0072462185920098955 (500) alberi
# Best var: 0.006415199752737734
# Best number of Trees: 100
#
# Validation: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.018500676444995708 (500) alberi
# Best mse: 0.018231301499613328
# Best number of Trees: 380
#
# Punteggio finale: 0.01577445463481784 (500) alberi
# Best bias: 0.015631082756744172
# Best number of Trees: 50
#
# Punteggio finale: 0.002726221810177867 (500) alberi
# Best var: 0.002170060621214766
# Best number of Trees: 30
#
# Wall time: 29.7 s

# %%
# %%time
rf_model.append(
    get_rf(
        2,
        verbose = False,
        debug   = False#,
        #file_name = 'Prova2'
    )
)
# Out:
# sostituisco 10
# sostituisco 20
# sostituisco 40
# sostituisco 60
# Train: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.005571554016823054 (500) alberi
# Best mse: 0.005284613977026978
# Best number of Trees: 10
#
# Punteggio finale: 0.003959184137465541 (500) alberi
# Best bias: 0.003959038514659924
# Best number of Trees: 110
#
# Punteggio finale: 0.001612369879357512 (500) alberi
# Best var: 0.0012957378835977626
# Best number of Trees: 10
#
# Validation: TUNING DEL MASSIMO NUMERO DI ALBERI NELLA FORESTA
#
# Punteggio finale: 0.001102700412296296 (500) alberi
# Best mse: 0.0009076367606198721
# Best number of Trees: 60
#
# Punteggio finale: 0.0007884564705103599 (500) alberi
# Best bias: 0.0005884451926675151
# Best number of Trees: 40
#
# Punteggio finale: 0.00031424394178593604 (500) alberi
# Best var: 0.0002711245868233548
# Best number of Trees: 210
#
# Wall time: 26 s

# %%
rf_model
# Out:
# [RandomForestRegressor(n_estimators=210, n_jobs=-1),
#  RandomForestRegressor(n_estimators=380, n_jobs=-1),
#  RandomForestRegressor(n_estimators=60, n_jobs=-1)]

# %%
def print_stats(X, y, models):
    for i in range(3):
        print(f'{region_names[i]}: {get_bias_var_mse(X[i], y[i].values.ravel(), models[i])}')
        print()

# %%
def print_all_stats(models):
    for X, y, name in zip(
        [X_train,        X_val, X_test],
        [y_train,        y_val, y_test],
        ['Train', 'Validation', 'Test']
    ):
        print(name)
        print()
        print_stats(X, y, models)
        print()

# %%
print_all_stats(rf_model)
# Out:
# Train
#
# A: {'bias': 0.007106451105949737, 'var': 0.0009018458871501911, 'mse': 0.008008296993099887}
#
# B: {'bias': 0.008288235943744707, 'var': 0.0035168442581161793, 'mse': 0.011805080201860893}
#
# C: {'bias': 0.011215866119074809, 'var': 0.0006121174180973323, 'mse': 0.011827983537172185}
#
#
# Validation
#
# A: {'bias': 0.027408995315531343, 'var': 0.0009122270245271408, 'mse': 0.028321222340058478}
#
# B: {'bias': 0.02019054472866314, 'var': 0.003532869661892454, 'mse': 0.02372341439055559}
#
# C: {'bias': 0.023722069126590493, 'var': 0.0006251963723824068, 'mse': 0.024347265498972946}
#
#
# Test
#
# A: {'bias': 0.02869406611117923, 'var': 0.0009089642009617785, 'mse': 0.029603030312141034}
#
# B: {'bias': 0.024512642353117026, 'var': 0.0036152589095000973, 'mse': 0.028127901262617116}
#
# C: {'bias': 0.026116245537518044, 'var': 0.000607462368740083, 'mse': 0.026723707906258026}

# %%
def feature_importance(X, rf, reg_name, file_name=''):
    
    print(f'{reg_name} FEATURE IMPORTANCES')
    print(list(X.columns[np.argsort(rf.feature_importances_)[::-1]]))
    print()
    
    fig, ax = plt.subplots(figsize=(len(rf.feature_importances_)/2,10))
    
    ax.tick_params(axis='x', which='major', labelsize=15)
    ax.tick_params(axis='x', which='minor', labelsize=20)
    ax.tick_params(axis='y', which='major', labelsize=25)
    ax.tick_params(axis='y', which='minor', labelsize=30)
    
    ax.bar(range(0, X.shape[1]), rf.feature_importances_)
    ax.set_title(f'Feature Importances {reg_name}')
    ax.set_xticks(range(X.shape[1]))
    ax.set_xticklabels(X.columns, rotation=90)
    
    ax.grid()
    
    if file_name != '':
        fig.savefig('images/' + file_name + '_RandomForestRegressor_FeatureImportance.jpg')

# %%
def get_feature_importance(index, file_name=''):
    if file_name == '':
        file_name = region_ids[i]
    feature_importance(
        X_train[i],
        rf_model[i],
        region_names[i],
        file_name = file_name
    )

# %%
get_feature_importance(0)
# Out:
# A FEATURE IMPORTANCES
# ['tax_prop', 'longitude', 'taxvaluedollarcnt', 'yearbuilt', 'taxamount', 'latitude', 'landtaxvaluedollarcnt', 'rawcensustractandblock', 'lotsizesquarefeet', 'tax_ratio', 'structuretaxvaluedollarcnt', 'int_transactiondate', 'neighborhood_mean_price', 'regionidzip', 'bedroomcnt', 'period_mean_price', 'living_area_prop', 'regionidcity', 'calculatedbathnbr', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'roomcnt', 'fireplacecnt', 'propertycountylandusecode_34', 'poolcnt_1.0', 'assessmentyear', 'propertylandusetypeid_266.0', 'propertylandusetypeid_261.0', 'propertycountylandusecode_122', 'propertycountylandusecode_rare', 'heatingorsystemtypeid_6.0', 'unitcnt', 'unitcnt_na_flag', 'heatingorsystemtypeid_24.0', 'propertylandusetypeid_246.0', 'propertylandusetypeid_247.0', 'heatingorsystemtypeid_18.0', 'heatingorsystemtypeid_7.0', 'propertylandusetypeid_248.0', 'propertylandusetypeid_260.0']

# %%
get_feature_importance(1)
# Out:
# A FEATURE IMPORTANCES
# ['tax_prop', 'longitude', 'taxvaluedollarcnt', 'yearbuilt', 'taxamount', 'latitude', 'landtaxvaluedollarcnt', 'rawcensustractandblock', 'lotsizesquarefeet', 'tax_ratio', 'structuretaxvaluedollarcnt', 'int_transactiondate', 'neighborhood_mean_price', 'regionidzip', 'bedroomcnt', 'period_mean_price', 'living_area_prop', 'regionidcity', 'calculatedbathnbr', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'roomcnt', 'fireplacecnt', 'propertycountylandusecode_34', 'poolcnt_1.0', 'assessmentyear', 'propertylandusetypeid_266.0', 'propertylandusetypeid_261.0', 'propertycountylandusecode_122', 'propertycountylandusecode_rare', 'heatingorsystemtypeid_6.0', 'unitcnt', 'unitcnt_na_flag', 'heatingorsystemtypeid_24.0', 'propertylandusetypeid_246.0', 'propertylandusetypeid_247.0', 'heatingorsystemtypeid_18.0', 'heatingorsystemtypeid_7.0', 'propertylandusetypeid_248.0', 'propertylandusetypeid_260.0']

# %%
get_feature_importance(2)
# Out:
# A FEATURE IMPORTANCES
# ['tax_prop', 'longitude', 'taxvaluedollarcnt', 'yearbuilt', 'taxamount', 'latitude', 'landtaxvaluedollarcnt', 'rawcensustractandblock', 'lotsizesquarefeet', 'tax_ratio', 'structuretaxvaluedollarcnt', 'int_transactiondate', 'neighborhood_mean_price', 'regionidzip', 'bedroomcnt', 'period_mean_price', 'living_area_prop', 'regionidcity', 'calculatedbathnbr', 'bathroomcnt', 'calculatedfinishedsquarefeet', 'finishedsquarefeet12', 'roomcnt', 'fireplacecnt', 'propertycountylandusecode_34', 'poolcnt_1.0', 'assessmentyear', 'propertylandusetypeid_266.0', 'propertylandusetypeid_261.0', 'propertycountylandusecode_122', 'propertycountylandusecode_rare', 'heatingorsystemtypeid_6.0', 'unitcnt', 'unitcnt_na_flag', 'heatingorsystemtypeid_24.0', 'propertylandusetypeid_246.0', 'propertylandusetypeid_247.0', 'heatingorsystemtypeid_18.0', 'heatingorsystemtypeid_7.0', 'propertylandusetypeid_248.0', 'propertylandusetypeid_260.0']

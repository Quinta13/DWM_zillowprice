# %%
# jupyter-nbconvert --to PDFviaHTML example.ipynb

# %%
fp_2016 = "datasets/properties_2016.csv"
fp_2017 = "datasets/properties_2017.csv"
fp_sub  = "datasets/sample_submission.csv"
fp_train_2016 = "datasets/train_2016_v2.csv"
fp_train_2017 = "datasets/train_2017.csv"
osservation_cnt = 50000

# %%
import pandas as pd
import numpy as np

df_2016 = pd.read_csv(fp_2016, nrows=osservation_cnt, low_memory=False)
df_2017 = pd.read_csv(fp_2017, nrows=osservation_cnt, low_memory=False)
df_sub  = pd.read_csv(fp_sub, nrows=osservation_cnt, low_memory=False)
df_train_2016 = pd.read_csv(fp_train_2016, nrows=osservation_cnt, low_memory=False)
df_train_2017 = pd.read_csv(fp_train_2017, nrows=osservation_cnt, low_memory=False)

# %%
df_2016.transpose()

# %%
#df_2017.transpose()

# %%
#df_sub.transpose()

# %%
#df_train_2016.transpose()

# %%
#df_train_2017.transpose()

# %%
df_2016.info()

# %% [markdown]
# ## Rimozione colonne con molti Nan ##

# %%
# Given the dataframe and the name of the column returns the column
def get_col(df, colName):
    return df.loc[:, colName]

# Given a column returns Nan-count and Nan-percentage
def get_col_nan_info(col):
    count = col.isna().sum()
    tot = len(col)
    perc = count/tot
    return count, perc

# Given the df and a treshold returns a list of column names with Nan-percentage greater or equal the treshold
def get_cols_over_nan_percentage(df, treshold):
    names = df.columns
    overPercentage = []
    for name in names:
        col = get_col(df, name)
        _ , perc = get_col_nan_info(col)
        # print(f'{name}: {perc})')
        if perc > treshold:
            overPercentage.append(name)
    return overPercentage

over_nan = get_cols_over_nan_percentage(df_2016, 0.7)

for o in over_nan:
    print(f'{o} : {get_col_nan_info(get_col(df_2016, o))}')
print(f'Legth: {len(over_nan)}')
# Out:
# airconditioningtypeid : (36044, 0.72088)
# architecturalstyletypeid : (49902, 0.99804)
# basementsqft : (49970, 0.9994)
# buildingclasstypeid : (49747, 0.99494)
# decktypeid : (49670, 0.9934)
# finishedfloor1squarefeet : (46087, 0.92174)
# finishedsquarefeet13 : (49842, 0.99684)
# finishedsquarefeet15 : (46774, 0.93548)
# finishedsquarefeet50 : (46087, 0.92174)
# finishedsquarefeet6 : (49672, 0.99344)
# fireplacecnt : (44678, 0.89356)
# garagecarcnt : (35819, 0.71638)
# garagetotalsqft : (35819, 0.71638)
# hashottuborspa : (48918, 0.97836)
# poolcnt : (41070, 0.8214)
# poolsizesum : (49500, 0.99)
# pooltypeid10 : (49421, 0.98842)
# pooltypeid2 : (49497, 0.98994)
# pooltypeid7 : (41573, 0.83146)
# storytypeid : (49970, 0.9994)
# threequarterbathnbr : (45057, 0.90114)
# typeconstructiontypeid : (49898, 0.99796)
# yardbuildingsqft17 : (48410, 0.9682)
# yardbuildingsqft26 : (49952, 0.99904)
# numberofstories : (38843, 0.77686)
# fireplaceflag : (49921, 0.99842)
# taxdelinquencyflag : (49018, 0.98036)
# taxdelinquencyyear : (49018, 0.98036)
# Legth: 28

# %%
print(df_2016.shape)
df_2016 = df_2016.drop(over_nan, axis=1)
print(df_2016.shape)
# Out:
# (50000, 58)
# (50000, 30)

# %%
df_2016.transpose()
# Out:
#                                      0                1                2      \
# parcelid                          10754147         10759547         10843547
# bathroomcnt                            0.0              0.0              0.0
# bedroomcnt                             0.0              0.0              0.0
# buildingqualitytypeid                  NaN              NaN              NaN
# calculatedbathnbr                      NaN              NaN              NaN
# calculatedfinishedsquarefeet           NaN              NaN          73026.0
# finishedsquarefeet12                   NaN              NaN              NaN
# fips                                  6037             6037             6037
# fullbathcnt                            NaN              NaN              NaN
# heatingorsystemtypeid                  NaN              NaN              NaN
# latitude                          34144442         34140430         33989359
# longitude                       -118654084       -118625364       -118394633
# lotsizesquarefeet                  85768.0           4083.0          63085.0
# propertycountylandusecode             010D             0109             1200
# propertylandusetypeid                  269              261               47
# propertyzoningdesc                     NaN           LCA11*             LAC2
# rawcensustractandblock        60378002.041  60378001.011002  60377030.012017
# regionidcity                       37688.0          37688.0          51617.0
# regionidcounty                        3101             3101             3101
# regionidneighborhood                   NaN              NaN              NaN
# regionidzip                        96337.0          96337.0          96095.0
# roomcnt                                0.0              0.0              0.0
# unitcnt                                NaN              NaN              2.0
# yearbuilt                              NaN              NaN              NaN
# structuretaxvaluedollarcnt             NaN              NaN         650756.0
# taxvaluedollarcnt                      9.0          27516.0        1413387.0
# assessmentyear                        2015             2015             2015
# landtaxvaluedollarcnt                  9.0          27516.0         762631.0
# taxamount                              NaN              NaN         20800.37
# censustractandblock                    NaN              NaN              NaN
#
#                                         3                4             5      \
# parcelid                             10859147         10879947      10898347
# bathroomcnt                               0.0              0.0           0.0
# bedroomcnt                                0.0              0.0           0.0
# buildingqualitytypeid                     7.0              NaN           7.0
# calculatedbathnbr                         NaN              NaN           NaN
# calculatedfinishedsquarefeet           5068.0           1776.0        2400.0
# finishedsquarefeet12                      NaN              NaN           NaN
# fips                                     6037             6037          6037
# fullbathcnt                               NaN              NaN           NaN
# heatingorsystemtypeid                     NaN              NaN           NaN
# latitude                             34148863         34194168      34171873
# longitude                          -118437206       -118385816    -118380906
# lotsizesquarefeet                      7521.0           8512.0        2500.0
# propertycountylandusecode                1200             1210          1210
# propertylandusetypeid                      47               31            31
# propertyzoningdesc                       LAC2             LAM1          LAC4
# rawcensustractandblock        60371412.023001  60371232.052003  60371252.001
# regionidcity                          12447.0          12447.0       12447.0
# regionidcounty                           3101             3101          3101
# regionidneighborhood                  27080.0          46795.0       46795.0
# regionidzip                           96424.0          96450.0       96446.0
# roomcnt                                   0.0              0.0           0.0
# unitcnt                                   NaN              1.0           NaN
# yearbuilt                              1948.0           1947.0        1943.0
# structuretaxvaluedollarcnt           571346.0         193796.0      176383.0
# taxvaluedollarcnt                   1156834.0         433491.0      283315.0
# assessmentyear                           2015             2015          2015
# landtaxvaluedollarcnt                585488.0         239695.0      106932.0
# taxamount                            14557.57          5725.17       3661.28
# censustractandblock                       NaN              NaN           NaN
#
#                                        6                7      \
# parcelid                            10933547         10940747
# bathroomcnt                              0.0              0.0
# bedroomcnt                               0.0              0.0
# buildingqualitytypeid                    NaN              NaN
# calculatedbathnbr                        NaN              NaN
# calculatedfinishedsquarefeet             NaN           3611.0
# finishedsquarefeet12                     NaN              NaN
# fips                                    6037             6037
# fullbathcnt                              NaN              NaN
# heatingorsystemtypeid                    NaN              NaN
# latitude                            34131929         34171345
# longitude                         -118351474       -118314900
# lotsizesquarefeet                        NaN           5333.0
# propertycountylandusecode               010V             1210
# propertylandusetypeid                    260               31
# propertyzoningdesc                      LAC2           BUC4YY
# rawcensustractandblock        60371437.00101  60373108.003004
# regionidcity                         12447.0         396054.0
# regionidcounty                          3101             3101
# regionidneighborhood                274049.0              NaN
# regionidzip                          96049.0          96434.0
# roomcnt                                  0.0              0.0
# unitcnt                                  NaN              NaN
# yearbuilt                                NaN           1946.0
# structuretaxvaluedollarcnt          397945.0         101998.0
# taxvaluedollarcnt                   554573.0         688486.0
# assessmentyear                          2015             2015
# landtaxvaluedollarcnt               156628.0         586488.0
# taxamount                            6773.34          7857.84
# censustractandblock                      NaN              NaN
#
#                                         8                9      ...  \
# parcelid                             10954547         10976347  ...
# bathroomcnt                               0.0              0.0  ...
# bedroomcnt                                0.0              0.0  ...
# buildingqualitytypeid                     NaN              7.0  ...
# calculatedbathnbr                         NaN              NaN  ...
# calculatedfinishedsquarefeet              NaN           3754.0  ...
# finishedsquarefeet12                      NaN              NaN  ...
# fips                                     6037             6037  ...
# fullbathcnt                               NaN              NaN  ...
# heatingorsystemtypeid                     NaN              NaN  ...
# latitude                             34218210         34289776  ...
# longitude                          -118331311       -118432085  ...
# lotsizesquarefeet                    145865.0           7494.0  ...
# propertycountylandusecode                010D             1210  ...
# propertylandusetypeid                     269               31  ...
# propertyzoningdesc                      BUR1*            SFC2*  ...
# rawcensustractandblock        60373101.003001  60373202.023005  ...
# regionidcity                         396054.0          47547.0  ...
# regionidcounty                           3101             3101  ...
# regionidneighborhood                      NaN              NaN  ...
# regionidzip                           96436.0          96366.0  ...
# roomcnt                                   0.0              0.0  ...
# unitcnt                                   NaN              NaN  ...
# yearbuilt                                 NaN           1978.0  ...
# structuretaxvaluedollarcnt                NaN         218440.0  ...
# taxvaluedollarcnt                         9.0         261201.0  ...
# assessmentyear                           2015             2015  ...
# landtaxvaluedollarcnt                     9.0          42761.0  ...
# taxamount                                 NaN          4054.76  ...
# censustractandblock                       NaN              NaN  ...
#
#                                          49990             49991  \
# parcelid                              11923970          11924039
# bathroomcnt                                2.0               1.0
# bedroomcnt                                 3.0               3.0
# buildingqualitytypeid                      7.0               7.0
# calculatedbathnbr                          2.0               1.0
# calculatedfinishedsquarefeet            1392.0            1568.0
# finishedsquarefeet12                    1392.0            1568.0
# fips                                      6037              6037
# fullbathcnt                                2.0               1.0
# heatingorsystemtypeid                      2.0               7.0
# latitude                              34121955          34120982
# longitude                           -118075754        -118073581
# lotsizesquarefeet                       5815.0            5897.0
# propertycountylandusecode                 0100              0101
# propertylandusetypeid                      261               261
# propertyzoningdesc                       LCRA*            LCR1YY
# rawcensustractandblock         60374800.124002   60374800.124006
# regionidcity                           33837.0           33837.0
# regionidcounty                            3101              3101
# regionidneighborhood                       NaN               NaN
# regionidzip                            96514.0           96514.0
# roomcnt                                    0.0               0.0
# unitcnt                                    1.0               1.0
# yearbuilt                               1949.0            1907.0
# structuretaxvaluedollarcnt            105682.0          153788.0
# taxvaluedollarcnt                     496178.0          326095.0
# assessmentyear                            2015              2015
# landtaxvaluedollarcnt                 390496.0          172307.0
# taxamount                              5948.31           4116.69
# censustractandblock           60374800124002.0  60374800124006.0
#
#                                          49992             49993  \
# parcelid                              11924353          11924850
# bathroomcnt                                2.0               3.0
# bedroomcnt                                 4.0               4.0
# buildingqualitytypeid                      7.0               4.0
# calculatedbathnbr                          2.0               3.0
# calculatedfinishedsquarefeet            1273.0            2906.0
# finishedsquarefeet12                       NaN            2906.0
# fips                                      6037              6037
# fullbathcnt                                2.0               3.0
# heatingorsystemtypeid                      NaN               2.0
# latitude                              34115160          34123008
# longitude                           -118077982        -118067985
# lotsizesquarefeet                       7119.0            5325.0
# propertycountylandusecode                 0200              0101
# propertylandusetypeid                      246               261
# propertyzoningdesc                       LCR1*            LCR105
# rawcensustractandblock         60374800.123006      60374800.121
# regionidcity                           33837.0           50749.0
# regionidcounty                            3101              3101
# regionidneighborhood                       NaN               NaN
# regionidzip                            96514.0           96514.0
# roomcnt                                    0.0               0.0
# unitcnt                                    2.0               1.0
# yearbuilt                               1932.0            1989.0
# structuretaxvaluedollarcnt             78146.0          496183.0
# taxvaluedollarcnt                     200294.0         1036733.0
# assessmentyear                            2015              2015
# landtaxvaluedollarcnt                 122148.0          540550.0
# taxamount                              2798.76          12123.82
# censustractandblock           60374800123006.0  60374800121000.0
#
#                                          49994             49995  \
# parcelid                              11925111          11925564
# bathroomcnt                                1.0               2.0
# bedroomcnt                                 3.0               2.0
# buildingqualitytypeid                      7.0               4.0
# calculatedbathnbr                          1.0               2.0
# calculatedfinishedsquarefeet             899.0            1144.0
# finishedsquarefeet12                     899.0            1144.0
# fips                                      6037              6037
# fullbathcnt                                1.0               2.0
# heatingorsystemtypeid                      7.0               2.0
# latitude                              34119686          34115254
# longitude                           -118066130        -118062292
# lotsizesquarefeet                       4897.0           27681.0
# propertycountylandusecode                 0100              010C
# propertylandusetypeid                      261               266
# propertyzoningdesc                      TCR172             TCR2*
# rawcensustractandblock         60374318.003005   60374318.003004
# regionidcity                           14111.0           14111.0
# regionidcounty                            3101              3101
# regionidneighborhood                       NaN               NaN
# regionidzip                            96268.0           96517.0
# roomcnt                                    0.0               0.0
# unitcnt                                    1.0               1.0
# yearbuilt                               1950.0            1980.0
# structuretaxvaluedollarcnt            107202.0          147816.0
# taxvaluedollarcnt                     178663.0          539098.0
# assessmentyear                            2015              2015
# landtaxvaluedollarcnt                  71461.0          391282.0
# taxamount                              2254.94           6392.08
# censustractandblock           60374318003005.0  60374318003004.0
#
#                                          49996             49997  \
# parcelid                              11926454          11926898
# bathroomcnt                                3.0               6.0
# bedroomcnt                                 3.0               6.0
# buildingqualitytypeid                      4.0               4.0
# calculatedbathnbr                          3.0               6.0
# calculatedfinishedsquarefeet            1970.0            3154.0
# finishedsquarefeet12                    1970.0               NaN
# fips                                      6037              6037
# fullbathcnt                                3.0               6.0
# heatingorsystemtypeid                      2.0               NaN
# latitude                              34118651          34109888
# longitude                           -118056841        -118073107
# lotsizesquarefeet                      39021.0            6828.0
# propertycountylandusecode                 01DC              0200
# propertylandusetypeid                      266               246
# propertyzoningdesc                       LCRA*            TCR1YY
# rawcensustractandblock         60374318.002011   60374801.013001
# regionidcity                           50749.0           14111.0
# regionidcounty                            3101              3101
# regionidneighborhood                       NaN               NaN
# regionidzip                            96268.0           96517.0
# roomcnt                                    0.0               0.0
# unitcnt                                    1.0               2.0
# yearbuilt                               1988.0            2008.0
# structuretaxvaluedollarcnt            178157.0          400422.0
# taxvaluedollarcnt                     345418.0          524516.0
# assessmentyear                            2015              2015
# landtaxvaluedollarcnt                 167261.0          124094.0
# taxamount                               4271.2           6556.29
# censustractandblock           60374318002011.0  60374801013001.0
#
#                                          49998             49999
# parcelid                              11927297          11927727
# bathroomcnt                                3.0               3.0
# bedroomcnt                                 2.0               3.0
# buildingqualitytypeid                      4.0               7.0
# calculatedbathnbr                          3.0               3.0
# calculatedfinishedsquarefeet            1116.0            1640.0
# finishedsquarefeet12                    1116.0            1640.0
# fips                                      6037              6037
# fullbathcnt                                3.0               3.0
# heatingorsystemtypeid                      2.0               2.0
# latitude                              34108100          34109287
# longitude                           -118073000        -118061576
# lotsizesquarefeet                      32367.0            9157.0
# propertycountylandusecode                 010C              0100
# propertylandusetypeid                      266               261
# propertyzoningdesc                       TCR4*             TCR3*
# rawcensustractandblock         60374801.011006   60374319.003004
# regionidcity                           14111.0           14111.0
# regionidcounty                            3101              3101
# regionidneighborhood                       NaN               NaN
# regionidzip                            96517.0           96517.0
# roomcnt                                    0.0               0.0
# unitcnt                                    1.0               1.0
# yearbuilt                               1982.0            1939.0
# structuretaxvaluedollarcnt            112123.0          202453.0
# taxvaluedollarcnt                     140147.0          717449.0
# assessmentyear                            2015              2015
# landtaxvaluedollarcnt                  28024.0          514996.0
# taxamount                              1861.51          13141.07
# censustractandblock           60374801011006.0  60374319003004.0
#
# [30 rows x 50000 columns]

# %%
df_2016.info()

# %% [markdown]
# ## Rimozione righe con molti Nan ##

# %%
# Given the dataframe and the index of the row returns the row
def get_row(df, index):
    return df.loc[index, :]

# Given a row returns Nan-count and Nan-percentage
def get_row_nan_info(row):
    count = row.isna().sum()
    tot = len(row)
    perc = count/tot
    return count, perc

# Given the df and a treshold returns a list of row ids with Nan-percentage greater or equal the treshold
def get_rows_over_nan_percentage(df, idName, treshold):
    overPercentage = []
    overPercentage_indexes = []
    for i in df.index:
        row = get_row(df, i)
        _ , perc = get_row_nan_info(row)
        if perc > treshold:
            overPercentage.append(row[idName])
            overPercentage_indexes.append(i)
    return overPercentage, overPercentage_indexes

over_nan, indexes = get_rows_over_nan_percentage(df_2016, "parcelid", 0.5)

for o, i in zip(over_nan, indexes):   
    print(f'{o} : {get_row_nan_info(get_row(df_2016, i))}')
print(f'Legth: {len(over_nan)}')
# Out:
# 163187347 : (17, 0.5666666666666667)
# 163187348 : (17, 0.5666666666666667)
# 163187349 : (17, 0.5666666666666667)
# 14317550 : (16, 0.5333333333333333)
# 17312550 : (16, 0.5333333333333333)
# Legth: 5

# %%
print(df_2016.shape)
df_2016 = df_2016.drop(indexes, axis=0)
print(df_2016.shape)
# Out:
# (50000, 30)
# (49995, 30)

# %%
df_2016.transpose()

# %%
df_2016.info()

# %% [markdown]
# ## Controllo valori di tipo non numerico ##

# %%
def get_not_numeric_cols(df):
    
    def is_numeric(value):
        return value != np.int64 and\
               value != np.float64
    
    not_numeric = []
    for k, v in dict(df_2016.dtypes).items():
        if(is_numeric(v)):
            not_numeric.append(k)
    return not_numeric

not_numeric = get_not_numeric_cols(df_2016)

# %%
for nn in not_numeric:
    values = get_col(df_2016, nn).unique()
    print(f'{nn}:{values} ({len(values)})')
# Out:
# propertycountylandusecode:['010D' '0109' '1200' '1210' '010V' '300V' '0100' '0200' '010C' '0300'
#  '1204' '100V' '01HC' '120C' '040V' '1214' '0101' nan '070P' '0700' '1'
#  '128' '0' '1112' '5050' '1110' '1118' '1111' '1129' '1420' '1222' '1128'
#  '1310' '1117' '1333' '1116' '1410' '010E' '0104' '070D' '0108' '012C'
#  '0400' '0103' '01DC' '0201' '010M' '030V' '0110' '010F' '010G' '010H'
#  '0301' '0102' '020E' '020M' '0401' '0113' '0141' '122' '38' '135' '96'
#  '71' '73' '34' '0209' '040G' '010L' '012E' '0111' '1720' '1014' '012D'
#  '1213' '1201' '1321' '1444' '1421' '0140' '0123' '0133' '020G' '030G'
#  '105' '0204' '010T' '0120' '1202' '121G' '010X' '020V' '880V' '1120'
#  '0130' '0118' '01HE' '120G' '5060' '0131'] (100)
# propertyzoningdesc:[nan 'LCA11*' 'LAC2' ... 'SOR112000*' 'SLR16500*' 'SLC1*'] (1774)

# %% [markdown]
# Da chiedere!!!
# Per propertycountylandusecode
# Non so se la vicinanza numerica ha valore
# Si può castare a int convertendo dei caratteri in interi?
# Per propertyzonningdesc
# Non posso fare onehotencoding per 1000 valori diversi, possono accumunare targhe con prime lettere simili?

# %% [markdown]
# Controllo quante volte quei valori occorrono

# %%
for nn in not_numeric:
    values = (get_col(df_2016, nn)).value_counts()
    print(f'{nn}:{values}')
# Out:
# propertycountylandusecode:0100    19608
# 122      7862
# 0101     4447
# 010C     3876
# 1111     2440
#         ...
# 020M        1
# 0140        1
# 0131        1
# 120G        1
# 040G        1
# Name: propertycountylandusecode, Length: 99, dtype: int64
# propertyzoningdesc:LAR1          5090
# LAR3          1190
# LARS          1045
# LAR2           858
# LBR1N          780
#               ...
# SGR4*            1
# PDC1DP*          1
# LCR130000*       1
# SSR1PUD*         1
# TORPBLC          1
# Name: propertyzoningdesc, Length: 1773, dtype: int64

# %%
def set_other_to_infrequent(df, col_names, important):
    for col_name in col_names:
        col = get_col(df, col_name)
        names = list(col.value_counts().to_dict().keys())[0:important]
        is_important = []
        for val in col:
            is_important.append(val not in names)
        col[is_important] = 'other'

set_other_to_infrequent(df_2016, not_numeric, 10)
# Out:
# <ipython-input-11-424bd3565bff>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   col[is_important] = 'other'

# %%
for nn in not_numeric:
    values = (get_col(df_2016, nn)).value_counts()
    print(f'{nn}:{values}')
# Out:
# propertycountylandusecode:0100     19608
# 122       7862
# other     5358
# 0101      4447
# 010C      3876
# 1111      2440
# 34        1843
# 0200      1753
# 010D      1013
# 1          978
# 010E       817
# Name: propertycountylandusecode, dtype: int64
# propertyzoningdesc:other      38250
# LAR1        5090
# LAR3        1190
# LARS        1045
# LAR2         858
# LBR1N        780
# LARD1.5      717
# SCUR2        583
# LARA         522
# LARD2        490
# LARE11       470
# Name: propertyzoningdesc, dtype: int64

# %% [markdown]
# tengo le dieci più significative e le altre le metto in un unico gruppo?

# %% [markdown]
# ## Controllo se i valori sono discreti ##

# %%
def get_discrete(df, treshold):
    discretes = []
    for col_name in df.columns:
        values_count = len(get_col(df,col_name).unique())
        if values_count < treshold:
            discretes.append(col_name)
    return discretes

discretes = get_discrete(df_2016, 30)
print(f'{discretes} ({len(discretes)})')
# Out:
# ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'fips', 'fullbathcnt', 'heatingorsystemtypeid', 'propertycountylandusecode', 'propertylandusetypeid', 'propertyzoningdesc', 'regionidcounty', 'roomcnt', 'unitcnt', 'assessmentyear'] (14)

# %%
for discrete in discretes:
    values = get_col(df_2016, discrete).unique()
    print(f'{discrete} : {values} ({len(values)})')
# Out:
# bathroomcnt : [ 0.   2.   4.   3.   1.   2.5  3.5  5.   1.5  4.5  7.5  5.5  6.   7.
#  10.   8.   9.  12.  11.   8.5  6.5 13.   9.5 14.  20.  19.5] (26)
# bedroomcnt : [ 0.  4.  5.  2.  3.  1.  6.  7.  8. 12. 11.  9. 10. 14. 16.] (15)
# buildingqualitytypeid : [nan  7.  4. 10.  1. 12.  8.  3.  6.  9.] (10)
# calculatedbathnbr : [ nan  2.   4.   3.   1.   2.5  3.5  5.   1.5  4.5  7.5  5.5  6.   7.
#  10.   8.   9.  12.  11.   8.5  6.5 13.   9.5 14.  20.  19.5] (26)
# fips : [6037 6059 6111] (3)
# fullbathcnt : [nan  2.  4.  3.  1.  5.  7.  6. 10.  8.  9. 12. 11. 13. 14. 20. 19.] (17)
# heatingorsystemtypeid : [nan  2.  7. 20.  6. 13. 18. 24. 12. 10.] (10)
# propertycountylandusecode : ['010D' 'other' '0100' '0200' '010C' '0101' '1' '1111' '010E' '122' '34'] (11)
# propertylandusetypeid : [269 261  47  31 260 266 246 247 248 263 265 275 267 264] (14)
# propertyzoningdesc : ['other' 'LAR2' 'LAR3' 'LARA' 'LARD2' 'LAR1' 'LARD1.5' 'LARS' 'LARE11'
#  'SCUR2' 'LBR1N'] (11)
# regionidcounty : [3101 1286 2061] (3)
# roomcnt : [ 0.  8.  4.  5.  7.  6. 11.  3. 10.  9.  2. 12. 86. 13. 15. 18. 22. 14.
#   1. 19. nan] (21)
# unitcnt : [ nan   2.   1.   3.   5.   4.   9.  48.  13.  22.  26.  73.  16.  12.
#    6.   7.  29.  35. 127.  18.   8.  10. 199.  11.  77.] (25)
# assessmentyear : [2015 2014 2003] (3)

# %% [markdown]
# Note: bathroomcnt, bedroomcnt, buildingqualitytypeid, calculatedbathnbr, fullbathcnt, roomcnt, unitcnt  Sono ORDINALI <br>
# fips, assementyear, regionidcounty CATEGORIALI --> fare ONE-HOT-ENCODING (chiedere se fare fillna) <br>
# heatingorsystemtypeid, propertylandusetypeid capire se sono ORDINALI o CATEGORIALI ??? <br>

# %%
ordinal = ['bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'fullbathcnt', 'roomcnt', 'unitcnt']
categorical = ['fips', 'assessmentyear', 'regionidcounty'] + not_numeric

# %% [markdown]
# ## RIEMPIRE I nan ##

# %% [markdown]
# PRIMA: aggiungere colonne con 1 se c'è valore, 0 se c'è Nan

# %%
numerics = list(set(df_2016.columns) - set(discretes + not_numeric))
numerics = numerics + ordinal
print(numerics)
# Out:
# ['landtaxvaluedollarcnt', 'latitude', 'calculatedfinishedsquarefeet', 'longitude', 'rawcensustractandblock', 'lotsizesquarefeet', 'regionidcity', 'regionidzip', 'structuretaxvaluedollarcnt', 'taxamount', 'parcelid', 'finishedsquarefeet12', 'censustractandblock', 'yearbuilt', 'taxvaluedollarcnt', 'regionidneighborhood', 'bathroomcnt', 'bedroomcnt', 'buildingqualitytypeid', 'calculatedbathnbr', 'fullbathcnt', 'roomcnt', 'unitcnt']

# %%
def fill_nan_with_mean(df, col_names):
    # add a column that keeps orginal nan values
    df.loc[:,'NanCount'] = df[col_names].isna().astype(int).sum(axis=1)
    for col_name in col_names:
        col = get_col(df, col_name)
        col.fillna(value=col.mean(), inplace=True)
    
fill_nan_with_mean(df_2016, numerics)

# %%
df_2016[numerics].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 49995 entries, 0 to 49999
# Data columns (total 23 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   landtaxvaluedollarcnt         49995 non-null  float64
#  1   latitude                      49995 non-null  int64
#  2   calculatedfinishedsquarefeet  49995 non-null  float64
#  3   longitude                     49995 non-null  int64
#  4   rawcensustractandblock        49995 non-null  float64
#  5   lotsizesquarefeet             49995 non-null  float64
#  6   regionidcity                  49995 non-null  float64
#  7   regionidzip                   49995 non-null  float64
#  8   structuretaxvaluedollarcnt    49995 non-null  float64
#  9   taxamount                     49995 non-null  float64
#  10  parcelid                      49995 non-null  int64
#  11  finishedsquarefeet12          49995 non-null  float64
#  12  censustractandblock           49995 non-null  float64
#  13  yearbuilt                     49995 non-null  float64
#  14  taxvaluedollarcnt             49995 non-null  float64
#  15  regionidneighborhood          49995 non-null  float64
#  16  bathroomcnt                   49995 non-null  float64
#  17  bedroomcnt                    49995 non-null  float64
#  18  buildingqualitytypeid         49995 non-null  float64
#  19  calculatedbathnbr             49995 non-null  float64
#  20  fullbathcnt                   49995 non-null  float64
#  21  roomcnt                       49995 non-null  float64
#  22  unitcnt                       49995 non-null  float64
# dtypes: float64(20), int64(3)
# memory usage: 10.2 MB

# %% [markdown]
# ## One-Hot encoding ##
